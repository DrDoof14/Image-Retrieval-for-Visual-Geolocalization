# %% [markdown]
# # 1. imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.1directories

# %%
import os 
# !pip install staticmap
from datetime import datetime
import cv2
import random
from PIL import Image
import time
from matplotlib import pyplot as plt
import time

project_directory = '/content/drive/MyDrive'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for staticmap: filename=staticmap-0.5.5-py3-none-any.whl size=6460 sha256=ac927a8a2eaf55f58489ed3cbfb1ba40d6a7f9354d779a95b1e12d13119e8e6e
#   Stored in directory: /root/.cache/pip/wheels/50/63/73/30d7f8ce53bed292bd687965dc89b662cce1e4e315ad69eab4
# Successfully built staticmap
# ...

# %% [markdown]
# # 1.2.Installing required libraries

# %%
#  !pip install -r /content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main/requirements.txt

# %%
start_time = time.time()
try:
  
  import faiss
except:
  # !pip install faiss-gpu
# !pip install faiss-cpu 

try:
   import torchscan
except:
  # !pip install torchscan

try:
    import timm
except:
  # !pip install timm
try:
   import  transformers
except:
  # !pip install transformers



print('time is {} '.format(time.time() -start_time  ))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 12.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 78.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 26.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 86.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 104.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 2.Experiment with different optimizers

# %% [markdown]
# ## 3.1. AdamW - lr =  0.00001 , weight decay = 0.01

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')

# !python3 train.py --dataset_name=pitts30k --datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg' \
--backbone=resnet18conv4\
--aggregation=netvlad\
--epochs_num=10\
--num_workers=2\
--save_dir '/content/drive/MyDrive/MLDL/results/AdamW'\
--optim 'AdamW'\
--weight_decay 0.01\
--lr 0.00001
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=10, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=2, off_the_shelf='imagenet', optim='AdamW', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume2=None, saturation=0, save_dir='/content/drive/MyDrive/MLDL/results/AdamW/2023-01-29_07-35-24', seed=0, test_
# ...

# %% [markdown]
# ## 3.2. AdamW with different parameters
# weight_decay : 0.05 <br>
# lr = 0.00001

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')

# !python3 train.py --dataset_name=pitts30k --datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg' \
--backbone=resnet18conv4\
--aggregation=netvlad\
--epochs_num=10\
--num_workers=2\
--save_dir '/content/drive/MyDrive/MLDL/results/AdamW2'\
--optim 'AdamW'\
--weight_decay 0.05\
--lr 0.00001
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=10, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=2, off_the_shelf='imagenet', optim='AdamW', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume2=None, saturation=0, save_dir='/content/drive/MyDrive/MLDL/results/AdamW2/2023-01-29_11-07-57', seed=0, test
# ...

# %% [markdown]
# ## 3.3. AdamW with different parameters
# lr = 0.001 <br>
# weight decay = 0.01

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')
# !python3 train.py --dataset_name=pitts30k --datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg' \
--backbone=resnet18conv4\
--aggregation=netvlad\
--epochs_num=10\
--num_workers=2\
--save_dir '/content/drive/MyDrive/MLDL/results/AdamW3'\
--optim 'AdamW'\
--weight_decay 0.01\
--lr 0.001
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=10, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=0.001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=2, off_the_shelf='imagenet', optim='AdamW', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume2=None, saturation=0, save_dir='/content/drive/MyDrive/MLDL/results/AdamW3/2023-01-30_13-58-59', seed=0, test
# ...

# %% [markdown]
# ## 3.3. AdamW with lr : 0.0001 and weight_decay 0.05

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')

# !python3 train.py --dataset_name=pitts30k --datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg' \
--backbone=resnet18conv4\
--aggregation=netvlad\
--epochs_num=10\
--num_workers=2\
--save_dir '/content/drive/MyDrive/MLDL/results/AdamW3'\
--optim 'AdamW'\
--weight_decay 0.05\
--lr 0.0001
# in the next experiment we increase the value for weight decay to avoid overfitting
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=10, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=2, off_the_shelf='imagenet', optim='AdamW', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume2=None, saturation=0, save_dir='/content/drive/MyDrive/MLDL/results/AdamW3/2023-02-02_11-41-16', seed=0, tes
# ...

# %% [markdown]
# ## 3.4. AdamW with  lr : 0.0001 and weight_decay 0.1

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')

# !python3 train.py --dataset_name=pitts30k --datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg' \
--backbone=resnet18conv4\
--aggregation=netvlad\
--epochs_num=10\
--num_workers=2\
--save_dir '/content/drive/MyDrive/MLDL/results/AdamW4'\
--optim 'AdamW'\
--weight_decay 0.1\
--lr 0.0001
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=10, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=2, off_the_shelf='imagenet', optim='AdamW', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume2=None, saturation=0, save_dir='/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-05_16-10-17', seed=0, tes
# ...

# %% [markdown]
# ## 3.5. AdamW with  lr : 0.0001 weight_decay 0.3

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')

# !python3 train.py --dataset_name=pitts30k --datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg' \
--backbone=resnet18conv4\
--aggregation=netvlad\
--epochs_num=10\
--num_workers=2\
--save_dir '/content/drive/MyDrive/MLDL/results/AdamW4'\
--optim 'AdamW'\
--weight_decay 0.3\
--lr 0.0001
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=10, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=2, off_the_shelf='imagenet', optim='AdamW', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume2=None, saturation=0, save_dir='/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-06_15-10-24', seed=0, tes
# ...

# %% [markdown]
# ## 4.1 testing sf_xs

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')
# !python3 eval.py  --datasets_folder '/content/drive/MyDrive/MLDL/sf-xs' \
--resume  '/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-06_15-10-24/best_model.pth'\
--dataset_name  'sf_xs' \
--backbone=resnet18conv4\
--aggregation=netvlad\
--save_dir '/content/drive/MyDrive/MLDL/results/adamw4/sf_xs'
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/MLDL/sf-xs', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-06_15-10-24/best_model.pth', resume2=None, saturation=0, save_dir='/content/d
# ...

# %% [markdown]
# ## 4.2 testing tokyo_xs

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')
# !python3 eval.py  --datasets_folder '/content/drive/MyDrive/MLDL/datasets_vg' \
--resume  '/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-06_15-10-24/best_model.pth'\
--dataset_name=tokyo_xs \
--backbone=resnet18conv4\
--aggregation=netvlad\
--save_dir '/content/drive/MyDrive/MLDL/results/adamw4/tokyo_xs'
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-06_15-10-24/best_model.pth', resume2=None, saturation=0, save_dir='/
# ...

# %% [markdown]
# ## 4.3 testing tokyo_night

# %%
os.chdir('/content/drive/MyDrive/MLDL/deep-visual-geo-localization-benchmark-main')
# !python3 eval.py  --datasets_folder '/content/drive/MyDrive/MLDL/datasets_vg' \
--resume '/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-06_15-10-24/best_model.pth'\
--dataset_name=tokyo_night \
--backbone=resnet18conv4\
--aggregation=netvlad\
--save_dir '/content/drive/MyDrive/MLDL/results/adamw4/tokyo_xs'
# Out:
# INFO:root:Arguments: Namespace(Ensembel=False, aggregation='netvlad', aggregation2='netvlad', backbone='resnet18conv4', brightness=0, cache_refresh_rate=1000, contrast=0, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/MLDL/datasets_vg', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=0, random_resized_crop=0, random_rotation=0, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/MLDL/results/AdamW4/2023-02-06_15-10-24/best_model.pth', resume2=None, saturation=0, save_dir
# ...
